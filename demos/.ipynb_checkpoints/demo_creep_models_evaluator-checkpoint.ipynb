# %% [markdown]
# # Creep Rheology Models Visualization
#
# This notebook explores various viscoelastic models to understand their behavior under creep loading. It uses pyRheo to compute the models given fixed parameter values.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-4, 4, 15)

# Parameters
model = "Maxwell"
G_s = 1e0
eta_s = 1e3

# Create a plasma colormap
cmap = cm.plasma

# Create figure and axis
plt.figure(figsize=(7,5))

params = [G_s, eta_s]
evaluator = CreepEvaluator(model=model) 
    
# Compute relaxation
J_creep = evaluator.compute_model(params, time)
    
# Select a color from the plasma colormap
color = cmap(1)  # Scale the color index
    
# Plotting storage modulus (G') on the upper plot
plt.plot(time, J_creep, 'o-', markersize=6, color=color, label="$J(t)$")
    
# Customize the plot
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r'$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="best")
plt.grid(False)

#plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "SpringPot"
V = 1e3

# Example alpha values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, alpha in enumerate(alpha_values):
    params = [V, alpha]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time)

    # Select a color from the plasma colormap
    color = cmap(i / len(alpha_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "FractionalMaxwellGel"
V = 1e3
G_s = 1e3

# Example alpha values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, alpha in enumerate(alpha_values):
    params = [V, G_s, alpha]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(alpha_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "FractionalMaxwellLiquid"
G = 1e3
eta_s = 1e3

# Example beta values
beta_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, beta in enumerate(beta_values):
    params = [G, eta_s, beta]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "FractionalMaxwell"
G = 1e3
V = 1e3

# Example alpha and beta values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.51]  
beta_values = [0.1, 0.2, 0.3, 0.4, 0.50]

# Create a plasma colormap
cmap = cm.plasma

# Create figure and axis
plt.figure(figsize=(7, 5))

# Loop over alpha and beta values
for i, (alpha, beta) in enumerate(zip(alpha_values, beta_values)):
    params = [G, V, alpha, beta]

    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}, $\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper left", bbox_to_anchor=(1.05, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# time and parameters
time = np.logspace(-3, 3, 15)
model = "FractionalKelvinVoigtS"
G_p = 1e3
V = 1e3

alpha_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

for i, alpha in enumerate(alpha_values):
    params = [G_p, V, alpha]
    evaluator = CreepEvaluator(model=model)
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type="Pade63")

    # Select a color from the plasma colormap
    color = cmap(i / len(alpha_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# FractionalKelvinVoigtD Model
time = np.logspace(-3, 3, 15)
model = "FractionalKelvinVoigtD"
G = 1e3
eta_p = 1e3

beta_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

for i, beta in enumerate(beta_values):
    params = [G, eta_p, beta]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type="Pade63")

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "FractionalKelvinVoigt"
G = 1e3
V = 1e3

# Example alpha and beta values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.51]  
beta_values = [0.1, 0.2, 0.3, 0.4, 0.50]

# Create a plasma colormap
cmap = cm.plasma

# Create figure and axis
plt.figure(figsize=(7, 5))

# Loop over alpha and beta values
for i, (alpha, beta) in enumerate(zip(alpha_values, beta_values)):
    params = [G, V, alpha, beta]

    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type="Pade63")

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}, $\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper left", bbox_to_anchor=(1.05, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-4, 4, 15)

# Parameters
model = "Zener"
G_s = 1e1
eta_s = 1e2
G_p = 1e1

# Create a plasma colormap
cmap = cm.plasma

# Create figure and axis
plt.figure(figsize=(7,5))

params = [G_p, G_s, eta_s]
evaluator = CreepEvaluator(model=model) 
    
# Compute relaxation
J_creep = evaluator.compute_model(params, time)
    
# Select a color from the plasma colormap
color = cmap(1)  # Scale the color index
    
# Plotting storage modulus (G') on the upper plot
plt.plot(time, J_creep, 'o-', markersize=6, color=color, label="$J(t)$")
    
# Customize the plot
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r'$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="best")
plt.grid(False)

#plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters for the model
model = "FractionalZenerSolidS"
G_p = 1e3
G_s = 1e3
V = 1e3

# Example alpha values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, alpha in enumerate(alpha_values):
    params = [G_p, G_s, V, alpha]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type="Pade72")

    # Select a color from the plasma colormap
    color = cmap(i / len(alpha_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
# FractionalZenerLiquidS Model
time = np.logspace(-3, 3, 15)

# Parameters for the model
model = "FractionalZenerLiquidS"
G_p = 1e3
G = 1e3
eta_s = 1e3

# Example beta values
beta_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, beta in enumerate(beta_values):
    params = [G_p, G, eta_s, beta]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
# FractionalZenerLiquidD Model
time = np.logspace(-3, 3, 15)

# Parameters for the model
model = "FractionalZenerLiquidD"
eta_s = 1e2
eta_p = 1e1
G = 1e3

# Example beta values
beta_values = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

# Create a plasma colormap
cmap = cm.plasma

# Create a figure
plt.figure(figsize=(7, 5))

# Loop over alpha values
for i, beta in enumerate(beta_values):
    params = [eta_s, eta_p, G, beta]
    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper right", bbox_to_anchor=(1.3, 1.0))
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from pyRheo.creep_evaluator import CreepEvaluator

# Example time values
time = np.logspace(-3, 3, 15)

# Parameters
model = "FractionalZenerS"
G_p = 1e3
G = 1e3
V = 1e3

# Example alpha and beta values
alpha_values = [0.9, 0.8, 0.7, 0.6, 0.51]  
beta_values = [0.1, 0.2, 0.3, 0.4, 0.50]

# Create a plasma colormap
cmap = cm.plasma

# Create figure and axis
plt.figure(figsize=(7, 5))

# Loop over alpha and beta values
for i, (alpha, beta) in enumerate(zip(alpha_values, beta_values)):
    params = [G_p, G, V, alpha, beta]

    evaluator = CreepEvaluator(model=model) 
    
    # Compute relaxation
    J_creep = evaluator.compute_model(params, time, mittag_leffler_type=None)

    # Select a color from the plasma colormap
    color = cmap(i / len(beta_values))  # Scale the color index

    # Plotting relaxation modulus vs. time
    plt.plot(time, J_creep, 'o-', markersize=6, label=f'$\\alpha$={alpha}, $\\beta$={beta}', color=color)

# Customize the plot
plt.tick_params(axis='both', which='major', labelsize=14)  # For major ticks
plt.tick_params(axis='both', which='minor', labelsize=10)  # For minor ticks
plt.xscale("log")
plt.yscale("log")
plt.xlabel('$t$ [s]', fontsize=14)
plt.ylabel('$J(t)$ [Pa$^{-1}$]', fontsize=14)
plt.legend(fontsize=13.5, loc="upper left", bbox_to_anchor=(1.05, 1.0))
plt.grid(False)

# Show the plot
plt.show()
